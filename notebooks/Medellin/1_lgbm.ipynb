# %%
import pandas as pd
import numpy as np
import joblib as jb

# %%
train_train_level0 = jb.load("train_train_level0.pkl.z")
train_train_level1 = jb.load("train_train_level1.pkl.z")
train_valid_level1 = jb.load("train_valid_level1.pkl.z")
test = pd.read_feather("test.f")


X_train0, y_train0 = train_train_level0.filter(regex=r'feature', axis=1), train_train_level0['target_kazutsugi']
X_train1, y_train1 = train_train_level1.filter(regex=r'feature', axis=1), train_train_level1['target_kazutsugi']
X_val1, y_val1 = train_valid_level1.filter(regex=r'feature', axis=1), train_valid_level1['target_kazutsugi']
X_test = test.filter(regex=r'feature', axis=1)

# %%
from scipy.stats import spearmanr

# %%
from lightgbm import LGBMRegressor
from skopt import gp_minimize


def tune_lgbm(params):
    num_leaves, min_data_in_leaf, learning_rate = params
    mdl = LGBMRegressor(num_leaves=num_leaves,min_data_in_leaf=min_data_in_leaf, learning_rate=learning_rate, 
                        n_estimators=100, random_state=0)
    mdl.fit(X_train0, y_train0)
    
    p = mdl.predict(X_train1)
    model_name_train1 = "./preds_train1/lgbm_{}_{}_{}.pkl.z".format(num_leaves, min_data_in_leaf, learning_rate) 
    jb.dump(p, model_name_train1)
    
    metric = spearmanr(y_train1.values,p).correlation
    
    p = mdl.predict(X_val1)
    model_name_val1 = "./preds_val1/lgbm_{}_{}_{}.pkl.z".format(num_leaves, min_data_in_leaf, learning_rate) 
    jb.dump(p, model_name_val1)
    
    p = mdl.predict(X_test)
    model_name_test = "./preds_test/lgbm_{}_{}_{}.pkl.z".format(num_leaves, min_data_in_leaf, learning_rate) 
    jb.dump(p, model_name_test)
    
    print(params, metric)
    print()
    
    return -metric

# %%
space = [(2, 200),
         (1, 1000),
         (1e-3, 1e-2, 'log-uniform')]

res = gp_minimize(tune_lgbm, space, random_state=0, verbose=1, n_calls=20)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [119, 844, 0.007210171877207321] 0.026955700020330455
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 12.6890
# Function value obtained: -0.0270
# Current minimum: -0.0270
# Iteration No: 2 started. Evaluating function at random point.
# [170, 624, 0.002423157857285798] 0.0214846981159758
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 15.0336
# Function value obtained: -0.0215
# Current minimum: -0.0270
# Iteration No: 3 started. Evaluating function at random point.
# [61, 58, 0.0018735112038624302] 0.019578402948099274
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 12.9609
# Function value obtained: -0.0196
# Current minimum: -0.0270
# Iteration No: 4 started. Evaluating function at random point.
# [97, 812, 0.0030197929882137525] 0.022529559135000904
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 13.3611
# Function value obtained: -0.0225
# Current minimum: -0.0270
# Iteration No: 5 started. Evaluating function at random point.
# [80, 836, 0.002174684006048089] 0.019906665784947004
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 11.8617
# Function value obtained: -0.0199
# Current minimum: -0.0270
# Iteration No: 6 started. Evaluating function at random point.
# [130, 369, 0.009060562467991657] 0.027170538676597786
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 13.7966
# Function value obtained: -0.0272
# Current minimum: -0.0272
# Iteration No: 7 started. Evaluating function at random point.
# [30, 870, 0.0029758295038874645] 0.021073447236912377
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 8.9069
# Function value obtained: -0.0211
# Current minimum: -0.0272
# Iteration No: 8 started. Evaluating function at random point.
# [161, 521, 0.004773968291550972] 0.024362688479182937
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 16.9938
# Function value obtained: -0.0244
# Current minimum: -0.0272
# Iteration No: 9 started. Evaluating function at random point.
# [145, 582, 0.003446459897310035] 0.02248120529257191
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 24.2824
# Function value obtained: -0.0225
# Current minimum: -0.0272
# Iteration No: 10 started. Evaluating function at random point.
# [152, 107, 0.0029757772507264775] 0.022672804381054543
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 21.2814
# Function value obtained: -0.0227
# Current minimum: -0.0272
# Iteration No: 11 started. Searching for the next optimal point.
# [200, 698, 0.01] 0.02914998725624185
#
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 15.0154
# Function value obtained: -0.0291
# Current minimum: -0.0291
# Iteration No: 12 started. Searching for the next optimal point.
# [200, 1000, 0.01] 0.02819489964181016
#
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 12.1217
# Function value obtained: -0.0282
# Current minimum: -0.0291
# Iteration No: 13 started. Searching for the next optimal point.
# [199, 120, 0.0010061841365898872] 0.019449545394298336
#
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 15.6237
# Function value obtained: -0.0194
# Current minimum: -0.0291
# Iteration No: 14 started. Searching for the next optimal point.
# [200, 1, 0.01] 0.024779409752965397
#
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 13.0010
# Function value obtained: -0.0248
# Current minimum: -0.0291
# Iteration No: 15 started. Searching for the next optimal point.
# [9, 959, 0.009971291384584463] 0.023164181803276354
#
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 7.3619
# Function value obtained: -0.0232
# Current minimum: -0.0291
# Iteration No: 16 started. Searching for the next optimal point.
# [4, 9, 0.00860236965078446] 0.01858755069370613
#
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 6.3338
# Function value obtained: -0.0186
# Current minimum: -0.0291
# Iteration No: 17 started. Searching for the next optimal point.
# [199, 993, 0.0010114080645134038] 0.018566167183649594
#
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 13.4632
# Function value obtained: -0.0186
# Current minimum: -0.0291
# Iteration No: 18 started. Searching for the next optimal point.
# [8, 979, 0.0010071644197231268] 0.0174516177262117
#
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 6.8060
# Function value obtained: -0.0175
# Current minimum: -0.0291
# Iteration No: 19 started. Searching for the next optimal point.
# [165, 766, 0.01] 0.02843173543980464
#
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 15.1476
# Function value obtained: -0.0284
# Current minimum: -0.0291
# Iteration No: 20 started. Searching for the next optimal point.
# [23, 4, 0.0010261458979516247] 0.017801796748834676
#
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 9.3367
# Function value obtained: -0.0178
# Current minimum: -0.0291

# %%
# fazer diário
